# %% [markdown]
# # Getting smiles 🙂

# %%
import pubchempy as pcp
import pandas as pd

def getSmiles(cid):
    c = pcp.Compound.from_cid(cid)
    return c.canonical_smiles

# %%
getSmiles(85470862)
# Out:
# 'C1=C(N=C(C(=O)N1)C(=O)N)F.[Na+]'

# %%
#23-Moléculas similares al Favipiravir:
similar_CID492405 = ['294642', '492405', "22674959", "67534452", "85470862", "89869520", "123273976", "135001386", "141329466", "144501910", "71812190", "72188728", "72201087", "76973015", "76973021", "76973034", "76973035", "76973036", "76973037", "131842118", "131846046", "135395256", "138708360"]

# %%
df_Favipiravir = pd.DataFrame(similar_CID492405)

# %%
df_Favipiravir.head()
# Out:
#           0
# 0    294642
# 1    492405
# 2  22674959
# 3  67534452
# 4  85470862

# %%
df_Favipiravir['SMILES']=df_Favipiravir.apply(lambda x: getSmiles(x[0]), axis=1) #Para conseguir el SMILES con el CID (por comprobar que la función funciona)

# %%
df_Favipiravir.head()
# Out:
#           0                           SMILES
# 0    294642           C1=CN=C(C(=O)N1)C(=O)N
# 1    492405        C1=C(N=C(C(=O)N1)C(=O)N)F
# 2  22674959        C1=C(NC(=O)C(=N1)C(=O)N)F
# 3  67534452              CNC(=O)C1=NC=CNC1=O
# 4  85470862  C1=C(N=C(C(=O)N1)C(=O)N)F.[Na+]

# %%
df = pcp.get_compounds('N04BB01', 'formula', as_dataframe=True)
df.head()
# Out:
#            atom_stereo_count  \
# cid
# 102419555                  0
#
#                                                        atoms  \
# cid
# 102419555  [{'aid': 1, 'number': 7, 'element': 'N', 'x': ...
#
#            bond_stereo_count  \
# cid
# 102419555                  0
#
#                                                        bonds  \
# cid
# 102419555  [{'aid1': 1, 'aid2': 3, 'order': 3}, {'aid1': ...
#
#                                           cactvs_fingerprint  \
# cid
# 102419555  0000001100000011100000000000000000000000000000...
#
#             canonical_smiles  charge  complexity conformer_id_3d  \
# cid
# 102419555  B(=B[N+]#N)[N+]#N       2         119            None
#
#           conformer_rmsd_3d  ... pharmacophore_features_3d  \
# cid                          ...
# 102419555              None  ...                      None
#
#                                                       record  \
# cid
# 102419555  {'id': {'id': {'cid': 102419555}}, 'atoms': {'...
# ...

# %%
df['CID'] = df.index #Para convertir el índice en una columna
df['SMILES']=df.apply(lambda x: getSmiles(x.CID), axis=1) #Para conseguir el SMILES con el CID (por comprobar que la función funciona)
df.head()
# Out:
#            atom_stereo_count  \
# cid
# 20271                      0
# 10808570                   3
# 23148745                   1
# 14350915                   3
# 122583731                  1
#
#                                                        atoms  \
# cid
# 20271      [{'aid': 1, 'number': 35, 'element': 'Br', 'y'...
# 10808570   [{'aid': 1, 'number': 35, 'element': 'Br', 'y'...
# 23148745   [{'aid': 1, 'number': 35, 'element': 'Br', 'y'...
# 14350915   [{'aid': 1, 'number': 35, 'element': 'Br', 'y'...
# 122583731  [{'aid': 1, 'number': 35, 'element': 'Br', 'y'...
#
#            bond_stereo_count  \
# cid
# 20271                      0
# 10808570                   0
# 23148745                   0
# 14350915                   0
# 122583731                  0
#
#                                                        bonds  \
# cid
# 20271      [{'aid1': 1, 'aid2': 20, 'order': 1}, {'aid1':...
# 10808570   [{'aid1': 1, 'aid2': 21, 'order': 1}, {'aid1':...
# ...

# %%
cs = pcp.get_compounds('C20H41Br', 'formula')
df4 = pcp.compounds_to_frame(cs, properties=['isomeric_smiles', 'xlogp', 'rotatable_bond_count'])
